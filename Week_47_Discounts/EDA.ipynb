# %% [markdown]
# ## Sales/Discounts by country, segement
# Make a timeline plot of sales activity
# groupby country or market segment
# draw a line plot of cumulative sales by selected country or market segment

# %%
import polars as pl
df = (
    pl.read_csv('Sales.csv')
    .select(
        DATE = pl.col('Order Date')
            .str.split(' ')
            .list.first()
            .str.to_date(format='%m/%d/%Y'),
        # ORDER = pl.col('Order ID'),
        # CUSTOMER = pl.col('Customer ID'),
        # LOCATION = pl.col('Location ID'),
        PRODUCT = pl.col('Product ID'),
        # QUANTITY = pl.col('Quantity').cast(pl.Int32),
        COST = pl.col('Sales').cast(pl.Float32),
        # DISCOUNT = pl.col('Discount').cast(pl.Float32),
        # SALES = pl.col('Sales').cast(pl.Float32),
        PROFIT = pl.col('Profit').cast(pl.Float32),
        COUNTRY = pl.col('Country').cast(pl.Categorical),
        SEGMENT = pl.col('Segment').cast(pl.Categorical),
    )
)
df
# Out:
# shape: (42_989, 6)
# ┌────────────┬─────────────┬─────────────┬────────────┬────────────────┬──────────┐
# │ DATE       ┆ PRODUCT     ┆ COST        ┆ PROFIT     ┆ COUNTRY        ┆ SEGMENT  │
# │ ---        ┆ ---         ┆ ---         ┆ ---        ┆ ---            ┆ ---      │
# │ date       ┆ str         ┆ f32         ┆ f32        ┆ cat            ┆ cat      │
# ╞════════════╪═════════════╪═════════════╪════════════╪════════════════╪══════════╡
# │ 2017-01-01 ┆ OFF-ST-6261 ┆ 408.299988  ┆ 106.139999 ┆ South Africa   ┆ Consumer │
# │ 2017-01-01 ┆ OFF-SU-3002 ┆ 120.365997  ┆ 36.035999  ┆ Australia      ┆ Consumer │
# │ 2017-01-01 ┆ FUR-FU-4075 ┆ 113.669998  ┆ 37.77      ┆ Australia      ┆ Consumer │
# │ 2017-01-01 ┆ OFF-PA-3990 ┆ 55.242001   ┆ 15.342     ┆ Australia      ┆ Consumer │
# │ 2017-01-01 ┆ OFF-ST-6230 ┆ 66.120003   ┆ 29.639999  ┆ United Kingdom ┆ Consumer │
# │ …          ┆ …           ┆ …           ┆ …          ┆ …              ┆ …        │
# │ 2020-08-24 ┆ TEC-PH-5817 ┆ 4367.895996 ┆ 327.592194 ┆ Pakistan       ┆ Consumer │
# │ 2020-08-24 ┆ OFF-AP-4240 ┆ 161.376007  ┆ 12.1032    ┆ Pakistan       ┆ Consumer │
# │ 2020-08-24 ┆ OFF-PA-4838 ┆ 49.568001   ┆ 15.49      ┆ Pakistan       ┆ Consumer │
# │ 2020-08-24 ┆ OFF-PA-3113 ┆ 8.72        ┆ 2.943      ┆ Pakistan       ┆ Consumer │
# │ 2020-08-24 ┆ FUR-FU-4092 ┆ 2.784       ┆ 0.4176     ┆ Pakistan       ┆ Consumer │
# └────────────┴─────────────┴─────────────┴────────────┴────────────────┴──────────┘
